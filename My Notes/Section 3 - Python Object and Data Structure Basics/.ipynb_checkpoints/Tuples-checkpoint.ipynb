# %%
t = (1,2,3)
#tuple

# %%
mylist = [1,2,3]
#list

# %%
t
# Out:
# (1, 2, 3)

# %%
t = ('one',2)

# %%
t[0]
# Out:
# 'one'

# %%
t[-1]
# Out:
# 2

# %%
t = ('a','a','b')

# %%
t.count('a')
# Out:
# 2

# %%
t.index('a')
# Out:
# 0

# %%
mylist
# Out:
# [1, 2, 3]

# %%
mylist[0] = 'new'

# %%
mylist
# Out:
# ['new', 2, 3]

# %%
t
# Out:
# ('a', 'a', 'b')

# %%
t[0] = 'b'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-ad4eacfd6ab3> in <module>
# ----> 1 t[0] = 'b'
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Tuple provides data integrity since it does not support re-assignment.
