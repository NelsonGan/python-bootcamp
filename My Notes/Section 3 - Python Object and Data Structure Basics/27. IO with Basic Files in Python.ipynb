# %%
# %%writefile myfile.txt
# Hello this is a text file
# This is the second line
# This is the third line
# Out:
# Writing myfile.txt

# %%
myfile = open('myfile.txt')

# %%
pwd
# Out:
# 'C:\\Users\\leong\\Desktop\\Udemy (Python)\\My Python Notes\\Python Object and Data Structure Basics'

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file\n',
#  'This is the second line\n',
#  'This is the third line\n']

# %% [markdown]
# File locations
#
# If you want to open files at another location on your computer, simply pass in the entire file path.
#
# For Windows you need to use double \ so python doesn't treat the second \ as an escape character, a file path is in the form:
#
#   myfile = open("C:\\Users\\UserName\\Folder\\test.txt")

# %%
pwd
# Out:
# 'C:\\Users\\leong\\Desktop\\Udemy (Python)\\My Python Notes\\Python Object and Data Structure Basics'

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
    contents = my_new_file.read()

# %%
contents
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'

# %%
with open('myfile.txt',mode='r') as myfile:
    contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file\nThis is the second line\nThis is the third line\n'

# %%
with open('myfile.txt',mode='w') as myfile:
    contents = myfile.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-24-e8147b9a81c0> in <module>
#       1 with open('myfile.txt',mode='w') as myfile:
# ----> 2     contents = myfile.read()
#
# UnsupportedOperation: not readable

# %% [markdown]
# Reading, Writing, Appending Modes
# . mode='r' is read only
#
# . mode='w' is write only (will overwrite files or create new!)
#
# . mode='a' is append only (will add on to files)
#
# . mode='r+' is reading and writing
#
# . mode='w+' is writing and reading (Overwrites existing files or creates a new file)

# %%
# %%writefile my_new_file.txt
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# Out:
# Overwriting my_new_file.txt

# %%
with open ('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD

# %%
with open ('my_new_file.txt',mode='a') as f:
    f.write('FOUR ON FOURTH')

# %%
with open ('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# FOUR ON FOURTH

# %%
with open ('pepega.txt',mode='w') as f:
    f.write('I CREATED THIS FILE!')

# %%
with open ('pepega.txt',mode='r') as f:
    print(f.read())
# Out:
# I CREATED THIS FILE!

# %%
# Out:
# C:\Users\leong
