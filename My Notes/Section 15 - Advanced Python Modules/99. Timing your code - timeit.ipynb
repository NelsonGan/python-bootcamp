# %%
import timeit

# %%
'0-1-2-3-....-99'
# Out:
# '0-1-2-3-....-99'

# %%
timeit.timeit('"-".join([str(n) for n in range(100)])',number=10000)
# Out:
# 0.2423217920000127

# %%
timeit.timeit('"-".join(map(str,range(100)))', number=10000)
# Out:
# 0.21063810600003308

# %%
# %timeit "-".join(str(n) for n in range(100))
# Out:
# 18 µs ± 236 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit "-".join([str(n) for n in range(100)])
# Out:
# 15.9 µs ± 174 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit "-".join(map(str,range(100)))
# Out:
# 12.6 µs ± 472 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
