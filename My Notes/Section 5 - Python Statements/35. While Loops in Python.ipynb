# %%
x = 50

while x < 5:
    print(f'The value of x is {x}')
    x += 1
else:
    print('X is not less than five')
# Out:
# X is not less than five

# %%
x = [1,2,3]

for item in x:
    #End loops (placeholder)
    pass

print('end of my script')
# Out:
# end of my script

# %%
mystring = 'Sammy'

for letter in mystring:
    if letter == 'a':
        continue
    print(letter)
# Out:
# S
# m
# m
# y

# %%
x = 0

while x < 5:
    print(x)
    x += 1
    if x == 2:
        break
# Out:
# 0
# 1

# %%
x = 34

while x > 10:
    x = x - 10
    if x <= 10:
        break

print(x)
# Out:
# 4
